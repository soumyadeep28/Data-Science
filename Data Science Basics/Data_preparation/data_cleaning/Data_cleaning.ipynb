# %%
# Import Lib
import pandas as pd
import numpy as np
import seaborn as sns
import os 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## IMPORT DATA -- Related problem and solution

# %%
# Read data set
#data = pd.read_csv('unclean_data.csv')  #  this line of code will give error wee need to check and update the codes#
# error you will get --> "UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 7: invalid start byte"
# --> for that solution : open text editor (subline) save as with encoding UTF-8 and save it .. after doing we got the new file Unclean_data1.csv 

# TYPE- 1 

data = pd.read_csv('unclean_data.csv' , encoding='latin')

# %%
data.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   movie_title                14 non-null     object
#  1   num_critic_for_reviews     14 non-null     int64
#  2   duration                   11 non-null     float64
#  3   DIRECTOR_facebook_likes    12 non-null     object
#  4   actor_3_facebook_likes     14 non-null     int64
#  5   ACTOR_1_facebook_likes     14 non-null     int64
#  6   gross                      14 non-null     int64
#  7   num_voted_users            13 non-null     float64
#  8   Cast_Total_facebook_likes  12 non-null     float64
#  9   facenumber_in_poster       9 non-null      float64
#  10  num_user_for_reviews       14 non-null     int64
#  11  budget                     14 non-null     int64
#  12  title_year                 14 non-null     int64
# ...

# %% [markdown]
# ## COLUMNS MODIFICATION --- process and code

# %% [markdown]
# Inconsist Column name
#
#
# - Update Case and Modification
# - Rename

# %% [markdown]
# ##### Update Case and Modification

# %%
data.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
# convert df column name into upper case
data.columns.str.upper()
# Out:
# Index(['MOVIE_TITLE', 'NUM_CRITIC_FOR_REVIEWS', 'DURATION',
#        'DIRECTOR_FACEBOOK_LIKES', 'ACTOR_3_FACEBOOK_LIKES',
#        'ACTOR_1_FACEBOOK_LIKES', 'GROSS', 'NUM_VOTED_USERS',
#        'CAST_TOTAL_FACEBOOK_LIKES', 'FACENUMBER_IN_POSTER',
#        'NUM_USER_FOR_REVIEWS', 'BUDGET', 'TITLE_YEAR',
#        'ACTOR_2_FACEBOOK_LIKES', 'IMDB_SCORE', 'TITLE_YEAR.1'],
#       dtype='object')

# %%
# convert df column name into lower case
data.columns.str.lower()
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes',
#        'actor_1_facebook_likes', 'gross', 'num_voted_users',
#        'cast_total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'actor_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %% [markdown]
# According to requirement need to save them into df column <br/>
# df.column = df.column.str.lower()

# %% [markdown]
# ##### Rename Columns

# %%
data.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %% [markdown]
# Now we will rename the column Duration and gross into new column name

# %%
data.rename(columns={'duration':'Time','budget':'Budget'})
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %% [markdown]
# ## Deal with Missing Data

# %% [markdown]
# - Add default values
# - Delete rows/columns
# - Interpolate the rows
# - Replace

# %%
#this will show is there any null value or not in tabuler form
data.isnull()
# Out:
#     movie_title  num_critic_for_reviews  duration  DIRECTOR_facebook_likes  \
# 0         False                   False     False                    False
# 1         False                   False      True                    False
# 2         False                   False     False                    False
# 3         False                   False      True                    False
# 4         False                   False     False                    False
# 5         False                   False     False                    False
# 6         False                   False      True                    False
# 7         False                   False     False                    False
# 8         False                   False     False                    False
# 9         False                   False     False                    False
# 10        False                   False     False                     True
# ...

# %%
#to check NULL value in table (overall view)
data.isnull().any()
# Out:
# movie_title                  False
# num_critic_for_reviews       False
# duration                      True
# DIRECTOR_facebook_likes       True
# actor_3_facebook_likes       False
# ACTOR_1_facebook_likes       False
# gross                        False
# num_voted_users               True
# Cast_Total_facebook_likes     True
# facenumber_in_poster          True
# num_user_for_reviews         False
# budget                       False
# title_year                   False
# ACTOR_2_facebook_likes        True
# imdb_score                   False
# title_year.1                  True
# dtype: bool

# %%
# to check if any null value all in a value
data.isnull().any().any()
# Out:
# True

# %%
## to check sum up of the null value
data.isnull().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     3
# DIRECTOR_facebook_likes      2
# actor_3_facebook_likes       0
# ACTOR_1_facebook_likes       0
# gross                        0
# num_voted_users              1
# Cast_Total_facebook_likes    2
# facenumber_in_poster         5
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# ACTOR_2_facebook_likes       1
# imdb_score                   0
# title_year.1                 7
# dtype: int64

# %%
# Fill emplty dataframe with empty value
DataDF_fillNA_with0 = data.fillna(0)

# %%
DataDF_fillNA_with0.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       0.0                     563                    1000
# 2     148.0                      20                     161
# 3       0.0                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
DataDF_fillNA_with0.isnull().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     0
# DIRECTOR_facebook_likes      0
# actor_3_facebook_likes       0
# ACTOR_1_facebook_likes       0
# gross                        0
# num_voted_users              0
# Cast_Total_facebook_likes    0
# facenumber_in_poster         0
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# ACTOR_2_facebook_likes       0
# imdb_score                   0
# title_year.1                 0
# dtype: int64

# %% [markdown]
# - FILL NA with MEAN process

# %%
print(data['duration'].head(5))
print("Total Empty values :" , data['duration'].isnull().sum())
print(round(data['duration'].mean(),2))
# Out:
# 0    178.0
# 1      NaN
# 2    148.0
# 3      NaN
# 4    132.0
# Name: duration, dtype: float64
# Total Empty values : 3
# 150.73

# %%
DataDF_fill_Mean = data.fillna(round(data['duration'].mean(),2))

# %%
DataDF_fill_Mean.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0    178.00                      10                     855
# 1    150.73                     563                    1000
# 2    148.00                      20                     161
# 3    150.73                   22000                   23000
# 4    132.00                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
## Drop Na rows  
print(data.shape)
data_dropna = data.dropna()
# Out:
# (14, 16)

# %%
data_dropna.shape
# Out:
# (4, 16)

# %%
## Drop Na columns
print(data.shape)
data_dropna_columns = data.dropna(axis = 1)
# Out:
# (14, 16)

# %%
data_dropna_columns.shape
# Out:
# (14, 9)

# %% [markdown]
# ##### Check DUplicate values

# %%
data.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
data.duplicated('movie_title')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# dtype: bool

# %%
data.duplicated('movie_title').sum() # NUM of duplicate values
# Out:
# 1

# %%
data.shape
# Out:
# (14, 16)

# %%
data_drop_duplicates = data.drop_duplicates('movie_title')     #have to mention the column name from which duplicate will be check

# %%
data_drop_duplicates.shape
# Out:
# (13, 16)

# %%
data_drop_duplicates.duplicated('movie_title')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# dtype: bool

# %% [markdown]
# ##### Change data type while importing the CSV file

# %%
data_newCustom = pd.read_csv('unclean_data1.csv' ,)

# %%
data_newCustom.dtypes
# Out:
# movie_title                   object
# num_critic_for_reviews         int64
# duration                     float64
# DIRECTOR_facebook_likes       object
# actor_3_facebook_likes         int64
# ACTOR_1_facebook_likes         int64
# gross                          int64
# num_voted_users              float64
# Cast_Total_facebook_likes    float64
# facenumber_in_poster         float64
# num_user_for_reviews           int64
# budget                         int64
# title_year                     int64
# ACTOR_2_facebook_likes       float64
# imdb_score                   float64
# title_year.1                 float64
# dtype: object

# %% [markdown]
# here we can see `num_critic_for_reviews` is mentioned as `int64` but we want to import as `float`

# %%
data_newCustom = pd.read_csv('unclean_data1.csv' ,dtype={'num_critic_for_reviews' : float})

# %%
data_newCustom.dtypes
# Out:
# movie_title                   object
# num_critic_for_reviews       float64
# duration                     float64
# DIRECTOR_facebook_likes       object
# actor_3_facebook_likes         int64
# ACTOR_1_facebook_likes         int64
# gross                          int64
# num_voted_users              float64
# Cast_Total_facebook_likes    float64
# facenumber_in_poster         float64
# num_user_for_reviews           int64
# budget                         int64
# title_year                     int64
# ACTOR_2_facebook_likes       float64
# imdb_score                   float64
# title_year.1                 float64
# dtype: object

# %%
## ANOTHER WAY TO CONVERT DATATYPE
data_newCustom.gross = data_newCustom.gross.astype('float')

# %%
data_newCustom.dtypes
# Out:
# movie_title                   object
# num_critic_for_reviews       float64
# duration                     float64
# DIRECTOR_facebook_likes       object
# actor_3_facebook_likes         int64
# ACTOR_1_facebook_likes         int64
# gross                        float64
# num_voted_users              float64
# Cast_Total_facebook_likes    float64
# facenumber_in_poster         float64
# num_user_for_reviews           int64
# budget                         int64
# title_year                     int64
# ACTOR_2_facebook_likes       float64
# imdb_score                   float64
# title_year.1                 float64
# dtype: object

# %% [markdown]
# ## EDIT ROWS/COLUMNS/ VALUES ....

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#    id         Full Name Date of Birth                         email  gender  \
# 0   1       Salim Pound     2/12/2018           spound0@spotify.com    Male
# 1   2    Madelene Lutas     9/20/2018                mlutas1@si.edu  Female
# 2   3  Dolli Swanbourne    11/18/2018  dswanbourne2@istockphoto.com  Female
# 3   4   Graeme Croisier     9/29/2018      gcroisier3@parallels.com    Male
# 4   5    Jillana Physic     4/19/2018       jphysic4@yellowbook.com  Female
#
#                            Job    Company                 Country  \
# 0                       Editor  Gigashots                  Israel
# 1                 VP Marketing     Wikivu                Mongolia
# 2          Associate Professor    Dabfeed                 Vietnam
# 3  Mechanical Systems Engineer     Trudoo  Bosnia and Herzegovina
# 4            Account Executive  Buzzshare                   China
#
#                                Salary         Phone  \
# 0  19QtDp5HkyuZZqwwqzYPSSLuA7MXFCwfKL  610-741-3882
# ...

# %%
df.columns
# Out:
# Index(['id', 'Full Name', 'Date of Birth', 'email', 'gender', 'Job', 'Company',
#        'Country', 'Salary', 'Phone', 'Quote', 'Income', 'Income.1'],
#       dtype='object')

# %% [markdown]
# here we can see there are different columns are there so we can edit the columns and modify accordingly .

# %%
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['id', 'full name', 'date of birth', 'email', 'gender', 'job', 'company',
#        'country', 'salary', 'phone', 'quote', 'income', 'income.1'],
#       dtype='object')

# %%
df.rename(columns={'full name':'full_name' , 'date of birth':'dob'} , inplace=True)

# %%
df.head()
# Out:
#    id         full_name         dob                         email  gender  \
# 0   1       Salim Pound   2/12/2018           spound0@spotify.com    Male
# 1   2    Madelene Lutas   9/20/2018                mlutas1@si.edu  Female
# 2   3  Dolli Swanbourne  11/18/2018  dswanbourne2@istockphoto.com  Female
# 3   4   Graeme Croisier   9/29/2018      gcroisier3@parallels.com    Male
# 4   5    Jillana Physic   4/19/2018       jphysic4@yellowbook.com  Female
#
#                            job    company                 country  \
# 0                       Editor  Gigashots                  Israel
# 1                 VP Marketing     Wikivu                Mongolia
# 2          Associate Professor    Dabfeed                 Vietnam
# 3  Mechanical Systems Engineer     Trudoo  Bosnia and Herzegovina
# 4            Account Executive  Buzzshare                   China
#
#                                salary         phone  \
# 0  19QtDp5HkyuZZqwwqzYPSSLuA7MXFCwfKL  610-741-3882
# ...
